# %%
import pandas as pd
import numpy as np
import urllib.request
import os
from tqdm import tqdm
import tensorflow as tf
from transformers import BertTokenizer, TFBertModel
import transformers
transformers.__version__
from sklearn.model_selection import StratifiedKFold
import tensorflow as tf

from transformers import TFBertForSequenceClassification
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from transformers import TextClassificationPipeline

from sklearn.utils import class_weight
from transformers import TextClassificationPipeline
from sklearn.metrics import accuracy_score

# %% [markdown]
# # 데이터 로드

# %%
dfp = pd.read_parquet('./df_minor_fill.pq')[['link',  'contents_clean','contents_nouns', 'y', 'y2']]
dfqe = pd.read_parquet('./df_35_noun.pq')[['link', 'contents_clean', 'contents_nouns', 'y', 'y2']]

# %%
X = np.array(dfp['contents_clean'].tolist())
y = np.array(dfp['y2num'].tolist())

# %% [markdown]
# # BERT fine-tuning

# %%
def convert_examples_to_features(examples, labels, max_seq_len, tokenizer):
    
    input_ids, attention_masks, token_type_ids, data_labels = [], [], [], []
    
    for example, label in tqdm(zip(examples, labels), total=len(examples)):
        input_id = tokenizer.encode(example, max_length=max_seq_len, pad_to_max_length=True)
        padding_count = input_id.count(tokenizer.pad_token_id)
        attention_mask = [1] * (max_seq_len - padding_count) + [0] * padding_count
        token_type_id = [0] * max_seq_len

        assert len(input_id) == max_seq_len, "Error with input length {} vs {}".format(len(input_id), max_seq_len)
        assert len(attention_mask) == max_seq_len, "Error with attention mask length {} vs {}".format(len(attention_mask), max_seq_len)
        assert len(token_type_id) == max_seq_len, "Error with token type length {} vs {}".format(len(token_type_id), max_seq_len)

        input_ids.append(input_id)
        attention_masks.append(attention_mask)
        token_type_ids.append(token_type_id)
        data_labels.append(label)

    input_ids = np.array(input_ids, dtype=int)
    attention_masks = np.array(attention_masks, dtype=int)
    token_type_ids = np.array(token_type_ids, dtype=int)

    data_labels = np.asarray(data_labels, dtype=np.int32)

    return (input_ids, attention_masks, token_type_ids), data_labels

# %%
# load tokenizer 
max_seq_len = 2028
tokenizer = BertTokenizer.from_pretrained('klue/bert-base', truncation=True, max_seq_len=max_seq_len)

# %%
## 라벨 숫자 인코딩
lbl_name = sorted(dfp['y2'].unique().tolist())
lbl_num = list(range(len(lbl_name)))
lbl_name2num = dict(zip(lbl_name,lbl_num))
lbl_num2name = dict(zip(lbl_num,lbl_name))
dfp['y2num']  = dfp.y2.apply(lambda x : lbl_name2num[x])

# %%
# 원큐
class_weights = class_weight.compute_class_weight(class_weight  = 'balanced',classes= np.unique(y), y = y) 
class_weights_dict = dict(zip(  list(range(len(class_weights))),class_weights))

X_train = tokenizer(X.tolist(), truncation=True, padding=True)


train_dataset = tf.data.Dataset.from_tensor_slices((
    dict(X_train),
    y
))


optimizer = tf.keras.optimizers.Adam(learning_rate=5e-5)
model = TFBertForSequenceClassification.from_pretrained("klue/bert-base", num_labels=dfp['y2num'].nunique(), from_pt=True)
loss =tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
metric = tf.keras.metrics.SparseCategoricalAccuracy('accuracy')
model.compile(optimizer=optimizer, loss=loss, metrics=[metric])

history =model.fit(
train_dataset.shuffle(1000).batch(16), epochs=7, batch_size=32,class_weight= class_weights_dict,)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertForSequenceClassification: ['bert.embeddings.position_ids']
# - This IS expected if you are initializing TFBertForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Epoch 1/7
# 178/178 [==============================] - 85s 419ms/step - loss: 2.9873 - accuracy: 0.2006
# Epoch 2/7
# 178/178 [==============================] - 75s 423ms/step - loss: 1.7373 - accuracy: 0.5950
# Epoch 3/7
# 178/178 [==============================] - 75s 422ms/step - loss: 1.0313 - accuracy: 0.7241
# Epoch 4/7
# 178/178 [==============================] - 75s 420ms/step - loss: 0.7557 - accuracy: 0.7695
# Epoch 5/7
# 178/178 [==============================] - 75s 422ms/step - loss: 0.4442 - accuracy: 0.8455
# Epoch 6/7
# 178/178 [==============================] - 75s 419ms/step - loss: 0.3114 - accuracy: 0.8909
# Epoch 7/7
# 178/178 [==============================] - 75s 419ms/step - loss: 0.2563 - accuracy: 0.9096

# %%
# 훈련모델 저장
model.save_weights('model_weights_real_v02', save_format='tf')
model.save_weights('model_weights_real_v02.h5', save_format='h5')

# %% [markdown]
# # 사용법

# %%
from transformers import BertTokenizer
from transformers import TFBertForSequenceClassification
from transformers import TextClassificationPipeline
max_seq_len = 2028
tokenizer = BertTokenizer.from_pretrained('klue/bert-base', truncation=True, max_seq_len=max_seq_len )
model = TFBertForSequenceClassification.from_pretrained("klue/bert-base", num_labels=len(lbl_num2name), from_pt=True)
model.load_weights('./model_weights_real_v02')

text_classifier = TextClassificationPipeline(
    tokenizer=tokenizer, 
    model=model, 
    framework='tf',
    return_all_scores=True , device=0
)
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertForSequenceClassification: ['bert.embeddings.position_ids']
# - This IS expected if you are initializing TFBertForSequenceClassification from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertForSequenceClassification from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights or buffers of the TF 2.0 model TFBertForSequenceClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# D:\anaconda3\envs\nlp38\lib\site-packages\transformers\pipelines\text_classification.py:89: UserWarning: `return_all_scores` is now deprecated, use `top_k=1` if you want similar functionnality
#   warnings.warn(

# %%
res = text_classifier('아버지가 방에 들어가신다')
res
# Out:
# [{'label': 'LABEL_0', 'score': 0.03188885748386383},
#  {'label': 'LABEL_1', 'score': 0.012798765674233437},
#  {'label': 'LABEL_2', 'score': 0.011650760658085346},
#  {'label': 'LABEL_3', 'score': 0.1136927604675293},
#  {'label': 'LABEL_4', 'score': 0.019805721938610077},
#  {'label': 'LABEL_5', 'score': 0.0225137360394001},
#  {'label': 'LABEL_6', 'score': 0.01153398398309946},
#  {'label': 'LABEL_7', 'score': 0.009569304995238781},
#  {'label': 'LABEL_8', 'score': 0.010257290676236153},
#  {'label': 'LABEL_9', 'score': 0.02755940891802311},
#  {'label': 'LABEL_10', 'score': 0.08993496745824814},
#  {'label': 'LABEL_11', 'score': 0.00900056678801775},
#  {'label': 'LABEL_12', 'score': 0.005275185685604811},
#  {'label': 'LABEL_13', 'score': 0.08223633468151093},
#  {'label': 'LABEL_14', 'score': 0.03501689434051514},
#  {'label': 'LABEL_15', 'score': 0.010377055034041405},
#  {'label': 'LABEL_16', 'score': 0.00671127624809742},
#  {'label': 'LABEL_17', 'score': 0.12466222792863846},
#  {'label': 'LABEL_18', 'score': 0.04239517077803612},
#  {'label': 'LABEL_19', 'score': 0.05364758521318436},
#  {'label': 'LABEL_20', 'score': 0.04118521139025688},
#  {'label': 'LABEL_21', 'score': 0.06328986585140228},
#  {'label': 'LABEL_22', 'score': 0.019293474033474922},
#  {'label': 'LABEL_23', 'score': 0.007870671339333057},
#  {'label': 'LABEL_24', 'score': 0.015573215670883656},
#  {'label': 'LABEL_25', 'score': 0.04203743487596512},
#  {'label': 'LABEL_26', 'score': 0.021111780777573586},
#  {'label': 'LABEL_27', 'score': 0.02781788259744644},
#  {'label': 'LABEL_28', 'score': 0.01732286438345909},
#  {'label': 'LABEL_29', 'score': 0.01396978460252285}]
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).classifier.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).classifier.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.embeddings.weight
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.embeddings.embeddings
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.embeddings.token_type_embeddings
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.embeddings.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.embeddings.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.pooler.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.pooler.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.0.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.1.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.2.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.3.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.4.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.5.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.6.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.7.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.8.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.9.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.10.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'm' for (root).bert.encoder.layer.11.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).classifier.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).classifier.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.embeddings.weight
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.embeddings.embeddings
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.embeddings.token_type_embeddings
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.embeddings.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.embeddings.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.pooler.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.pooler.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.0.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.0.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.0.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.0.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.0.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.0.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.1.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.1.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.1.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.1.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.1.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.1.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.2.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.2.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.2.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.2.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.2.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.2.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.3.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.3.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.3.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.3.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.3.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.3.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.4.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.4.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.4.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.4.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.4.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.4.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.bert_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.intermediate.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.intermediate.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.bert_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.bert_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.bert_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.bert_output.LayerNorm.beta
# ...
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.3.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.3.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.3.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.3.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.3.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.3.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.3.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.3.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.3.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.4.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.4.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.4.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.4.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.4.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.4.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.4.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.4.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.4.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.4.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.5.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.6.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.7.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.8.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.9.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.10.attention.dense_output.LayerNorm.beta
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.self_attention.query.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.self_attention.query.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.self_attention.key.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.self_attention.key.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.self_attention.value.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.self_attention.value.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.dense_output.dense.kernel
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.dense_output.dense.bias
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.dense_output.LayerNorm.gamma
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer's state 'v' for (root).bert.encoder.layer.11.attention.dense_output.LayerNorm.beta
